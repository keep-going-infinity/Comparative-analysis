# %%
# -----------------------------------------------------------
# Dissertation Project: An Empirical Study on the Classification 
# Performance of Deep Learning vs. Gradient Boosting 
# on heterogeneous tabular data
#
# This module provides the classification and ablation results for all models
#
# Author: Adam Mabrouk
# Supervisor: Ben Ralph
# Institution: University of Bath
# Created on: 01/01/2024
# Version: 1.0
# -----------------------------------------------------------

# Pandas version: 2.0.3
# Python version: 3.11.5

import os
import pandas as pd
from collections import defaultdict

metrics = ['TP', 'TN', 'FP', 'FN', 'Recall', 'Specificity', 
           'Accuracy', 'Precision', 'F1-score', 'G-Mean', 'AUROC', 'AUPRC']

def process_csv_file(file_path):
    """
    Process a single CSV file and return calculated metrics including FNR and FPR.
    """
    df = pd.read_csv(file_path)
    metric_values = defaultdict(list)

    for _, row in df.iterrows():
        metric = row["Metric"]
        if metric in metrics:
            metric_value = row["Value"]
            metric_values[metric].append(float(metric_value))
    
    TP, FN, FP, TN = [float(df[df['Metric'] == m]['Value'].values[0]) for m in ['TP', 'FN', 'FP', 'TN']]
    FNR = FN / (FN + TP) if (FN + TP) > 0 else 0
    FPR = FP / (FP + TN) if (FP + TN) > 0 else 0
    metric_values['FNR'].append(FNR)
    metric_values['FPR'].append(FPR)

    return metric_values

def calculate_metrics(metric_values):
    """
    Calculate mean and standard deviation for each metric.
    """
    results = {}
    for metric in metric_values:
        mean = pd.Series(metric_values[metric]).mean()
        std = pd.Series(metric_values[metric]).std()
        mean, std = round(mean * 100, 2) if metric not in ['TP', 'TN', 'FP', 'FN'] else round(mean, 2), round(std * 100, 2) if metric not in ['TP', 'TN', 'FP', 'FN'] else round(std, 2)
        results[metric] = {'mean': mean, 'std': std}
    return results

def process_folder(folder_path):
    """
    Process all CSV files in a given folder and calculate metrics.
    """
    all_metric_values = defaultdict(list)

    for file in os.listdir(folder_path):
        if file.endswith('.csv'):
            file_path = os.path.join(folder_path, file)
            metric_values = process_csv_file(file_path)

            for metric, values in metric_values.items():
                all_metric_values[metric].extend(values)

    return calculate_metrics(all_metric_values)

def process_base_folder(base_folders):
    """
    Process each subfolder within the base folders and print results.
    """
    for base_folder in base_folders:
        print('-------', base_folder, '-----\n\n')
        for sub_folder in os.listdir(base_folder):
            sub_folder_path = os.path.join(base_folder, sub_folder)
            if os.path.isdir(sub_folder_path):
                for data_set in os.listdir(sub_folder_path):
                    data_set_path = os.path.join(sub_folder_path, data_set)
                    if os.path.isdir(data_set_path):
                        folder_results = process_folder(data_set_path)
                        if folder_results:
                            print(f"Results for {data_set_path}:")
                            for metric, values in folder_results.items():
                                print(f"{metric}: Mean = {values['mean']}, Standard Deviation = {values['std']}")
                            print("\n")

base_folders = ['Model_results', 'Ablation']
process_base_folder(base_folders)
# Out:
# ------- Model_results -----
#
#
# Results for Model_results/node_results/node_adult_income:
# TP: Mean = 97.67, Standard Deviation = 5.6
# TN: Mean = 305.13, Standard Deviation = 15.72
# FP: Mean = 80.87, Standard Deviation = 15.72
# FN: Mean = 16.33, Standard Deviation = 5.6
# Specificity: Mean = 79.05, Standard Deviation = 4.07
# Accuracy: Mean = 80.56, Standard Deviation = 2.52
# Precision: Mean = 55.06, Standard Deviation = 3.79
# Recall: Mean = 85.67, Standard Deviation = 4.91
# F1-score: Mean = 66.86, Standard Deviation = 2.47
# G-Mean: Mean = 82.2, Standard Deviation = 1.77
# AUROC: Mean = 90.09, Standard Deviation = 1.51
# AUPRC: Mean = 71.32, Standard Deviation = 2.6
# FNR: Mean = 14.33, Standard Deviation = 4.91
# FPR: Mean = 20.95, Standard Deviation = 4.07
#
#
# Results for Model_results/node_results/node_heloc:
# TP: Mean = 162.8, Standard Deviation = 7.71
# TN: Mean = 188.07, Standard Deviation = 7.61
# FP: Mean = 74.93, Standard Deviation = 7.61
# FN: Mean = 74.2, Standard Deviation = 7.71
# Specificity: Mean = 71.51, Standard Deviation = 2.89
# Accuracy: Mean = 70.17, Standard Deviation = 0.81
# Precision: Mean = 68.55, Standard Deviation = 1.43
# Recall: Mean = 68.69, Standard Deviation = 3.25
# F1-score: Mean = 68.56, Standard Deviation = 1.31
# G-Mean: Mean = 70.03, Standard Deviation = 0.83
# AUROC: Mean = 75.17, Standard Deviation = 0.22
# AUPRC: Mean = 71.17, Standard Deviation = 0.68
# FNR: Mean = 31.31, Standard Deviation = 3.25
# FPR: Mean = 28.49, Standard Deviation = 2.89
#
#
# Results for Model_results/node_results/node_lending_club:
# TP: Mean = 256.8, Standard Deviation = 23.78
# TN: Mean = 60.47, Standard Deviation = 5.33
# FP: Mean = 30.53, Standard Deviation = 5.33
# FN: Mean = 152.2, Standard Deviation = 23.78
# Specificity: Mean = 66.45, Standard Deviation = 5.86
# Accuracy: Mean = 63.45, Standard Deviation = 3.76
# Precision: Mean = 89.44, Standard Deviation = 0.84
# Recall: Mean = 62.79, Standard Deviation = 5.81
# F1-score: Mean = 73.61, Standard Deviation = 3.71
# G-Mean: Mean = 64.35, Standard Deviation = 0.93
# AUROC: Mean = 70.58, Standard Deviation = 0.73
# AUPRC: Mean = 91.24, Standard Deviation = 0.29
# FNR: Mean = 37.21, Standard Deviation = 5.81
# FPR: Mean = 33.55, Standard Deviation = 5.86
#
#
# Results for Model_results/xgboost_results/xgboost_adult_income:
# TP: Mean = 106.67, Standard Deviation = 1.54
# TN: Mean = 290.33, Standard Deviation = 4.97
# FP: Mean = 95.67, Standard Deviation = 4.97
# FN: Mean = 7.33, Standard Deviation = 1.54
# Specificity: Mean = 75.22, Standard Deviation = 1.29
# Accuracy: Mean = 79.4, Standard Deviation = 1.01
# Precision: Mean = 52.75, Standard Deviation = 1.31
# Recall: Mean = 93.57, Standard Deviation = 1.35
# F1-score: Mean = 67.45, Standard Deviation = 1.18
# G-Mean: Mean = 83.89, Standard Deviation = 0.89
# AUROC: Mean = 84.39, Standard Deviation = 0.88
# AUPRC: Mean = 50.82, Standard Deviation = 1.36
# FNR: Mean = 6.43, Standard Deviation = 1.35
# FPR: Mean = 24.78, Standard Deviation = 1.29
#
#
# Results for Model_results/xgboost_results/xgboost_heloc:
# TP: Mean = 158.47, Standard Deviation = 3.98
# TN: Mean = 194.6, Standard Deviation = 5.23
# FP: Mean = 68.4, Standard Deviation = 5.23
# FN: Mean = 78.53, Standard Deviation = 3.98
# Specificity: Mean = 73.99, Standard Deviation = 1.99
# Accuracy: Mean = 70.61, Standard Deviation = 0.95
# Precision: Mean = 69.88, Standard Deviation = 1.41
# Recall: Mean = 66.86, Standard Deviation = 1.68
# F1-score: Mean = 68.32, Standard Deviation = 1.01
# G-Mean: Mean = 70.32, Standard Deviation = 0.93
# AUROC: Mean = 70.43, Standard Deviation = 0.94
# AUPRC: Mean = 62.43, Standard Deviation = 0.95
# FNR: Mean = 33.14, Standard Deviation = 1.68
# FPR: Mean = 26.01, Standard Deviation = 1.99
#
#
# Results for Model_results/xgboost_results/xgboost_lending_club:
# TP: Mean = 325.0, Standard Deviation = 8.94
# TN: Mean = 42.33, Standard Deviation = 4.35
# FP: Mean = 48.67, Standard Deviation = 4.35
# FN: Mean = 84.0, Standard Deviation = 8.94
# Specificity: Mean = 46.52, Standard Deviation = 4.78
# Accuracy: Mean = 73.47, Standard Deviation = 1.44
# Precision: Mean = 86.99, Standard Deviation = 0.86
# Recall: Mean = 79.46, Standard Deviation = 2.19
# F1-score: Mean = 83.04, Standard Deviation = 1.12
# G-Mean: Mean = 60.69, Standard Deviation = 2.72
# AUROC: Mean = 62.99, Standard Deviation = 1.93
# AUPRC: Mean = 85.92, Standard Deviation = 0.65
# FNR: Mean = 20.54, Standard Deviation = 2.19
# FPR: Mean = 53.48, Standard Deviation = 4.78
#
#
# Results for Model_results/tabnet_results/tabnet_adult_income:
# TP: Mean = 86.33, Standard Deviation = 16.97
# TN: Mean = 293.8, Standard Deviation = 33.44
# FP: Mean = 92.2, Standard Deviation = 33.44
# FN: Mean = 27.67, Standard Deviation = 16.97
# Specificity: Mean = 76.11, Standard Deviation = 8.66
# Accuracy: Mean = 76.03, Standard Deviation = 3.77
# Precision: Mean = 49.61, Standard Deviation = 5.2
# Recall: Mean = 75.73, Standard Deviation = 14.89
# F1-score: Mean = 58.77, Standard Deviation = 3.52
# G-Mean: Mean = 75.06, Standard Deviation = 4.46
# AUROC: Mean = 84.13, Standard Deviation = 2.89
# AUPRC: Mean = 58.87, Standard Deviation = 3.4
# FNR: Mean = 24.27, Standard Deviation = 14.89
# FPR: Mean = 23.89, Standard Deviation = 8.66
#
#
# Results for Model_results/tabnet_results/tabnet_heloc:
# TP: Mean = 160.73, Standard Deviation = 5.28
# TN: Mean = 188.67, Standard Deviation = 6.84
# FP: Mean = 74.33, Standard Deviation = 6.84
# FN: Mean = 76.27, Standard Deviation = 5.28
# Specificity: Mean = 71.74, Standard Deviation = 2.6
# Accuracy: Mean = 69.88, Standard Deviation = 0.68
# Precision: Mean = 68.44, Standard Deviation = 1.45
# Recall: Mean = 67.82, Standard Deviation = 2.23
# F1-score: Mean = 68.09, Standard Deviation = 0.77
# G-Mean: Mean = 69.71, Standard Deviation = 0.6
# AUROC: Mean = 76.05, Standard Deviation = 0.44
# AUPRC: Mean = 72.84, Standard Deviation = 0.75
# FNR: Mean = 32.18, Standard Deviation = 2.23
# FPR: Mean = 28.26, Standard Deviation = 2.6
#
#
# Results for Model_results/tabnet_results/tabnet_lending_club:
# TP: Mean = 266.93, Standard Deviation = 30.37
# TN: Mean = 42.87, Standard Deviation = 11.7
# FP: Mean = 48.13, Standard Deviation = 11.7
# FN: Mean = 142.07, Standard Deviation = 30.37
# Specificity: Mean = 47.11, Standard Deviation = 12.85
# Accuracy: Mean = 61.96, Standard Deviation = 4.66
# Precision: Mean = 84.86, Standard Deviation = 2.38
# Recall: Mean = 65.26, Standard Deviation = 7.42
# F1-score: Mean = 73.53, Standard Deviation = 4.38
# G-Mean: Mean = 54.53, Standard Deviation = 6.23
# AUROC: Mean = 59.98, Standard Deviation = 4.97
# AUPRC: Mean = 86.25, Standard Deviation = 2.16
# FNR: Mean = 34.74, Standard Deviation = 7.42
# FPR: Mean = 52.89, Standard Deviation = 12.85
#
#
# ------- Ablation -----
#
#
# Results for Ablation/ablation_tabnet/glu:
# TP: Mean = 281.7, Standard Deviation = 11.54
# TN: Mean = 56.3, Standard Deviation = 2.75
# FP: Mean = 34.7, Standard Deviation = 2.75
# FN: Mean = 127.3, Standard Deviation = 11.54
# Specificity: Mean = 61.87, Standard Deviation = 3.02
# Accuracy: Mean = 67.6, Standard Deviation = 2.07
# Precision: Mean = 89.04, Standard Deviation = 0.65
# Recall: Mean = 68.88, Standard Deviation = 2.82
# F1-score: Mean = 77.64, Standard Deviation = 1.8
# G-Mean: Mean = 65.23, Standard Deviation = 1.44
# AUROC: Mean = 70.7, Standard Deviation = 1.3
# AUPRC: Mean = 90.06, Standard Deviation = 0.75
# FNR: Mean = 31.12, Standard Deviation = 2.82
# FPR: Mean = 38.13, Standard Deviation = 3.02
#
#
# Results for Ablation/ablation_tabnet/mish:
# TP: Mean = 272.4, Standard Deviation = 13.99
# TN: Mean = 56.9, Standard Deviation = 3.96
# FP: Mean = 34.1, Standard Deviation = 3.96
# FN: Mean = 136.6, Standard Deviation = 13.99
# Specificity: Mean = 62.53, Standard Deviation = 4.35
# Accuracy: Mean = 65.86, Standard Deviation = 2.1
# Precision: Mean = 88.91, Standard Deviation = 0.73
# Recall: Mean = 66.6, Standard Deviation = 3.42
# F1-score: Mean = 76.1, Standard Deviation = 2.11
# G-Mean: Mean = 64.43, Standard Deviation = 1.01
# AUROC: Mean = 70.57, Standard Deviation = 1.14
# AUPRC: Mean = 89.84, Standard Deviation = 0.78
# FNR: Mean = 33.4, Standard Deviation = 3.42
# FPR: Mean = 37.47, Standard Deviation = 4.35
#
#
# Results for Ablation/ablation_tabnet/sparse_loss_strength:
# TP: Mean = 284.6, Standard Deviation = 11.07
# TN: Mean = 56.4, Standard Deviation = 2.8
# FP: Mean = 34.6, Standard Deviation = 2.8
# FN: Mean = 124.4, Standard Deviation = 11.07
# Specificity: Mean = 61.98, Standard Deviation = 3.07
# Accuracy: Mean = 68.2, Standard Deviation = 1.76
# Precision: Mean = 89.17, Standard Deviation = 0.49
# Recall: Mean = 69.58, Standard Deviation = 2.71
# F1-score: Mean = 78.14, Standard Deviation = 1.6
# G-Mean: Mean = 65.62, Standard Deviation = 0.85
# AUROC: Mean = 70.63, Standard Deviation = 0.72
# AUPRC: Mean = 90.05, Standard Deviation = 0.61
# FNR: Mean = 30.42, Standard Deviation = 2.71
# FPR: Mean = 38.02, Standard Deviation = 3.07
#
#
# Results for Ablation/ablation_tabnet/relaxation_factor:
# TP: Mean = 258.8, Standard Deviation = 30.81
# TN: Mean = 48.0, Standard Deviation = 8.51
# FP: Mean = 43.0, Standard Deviation = 8.51
# FN: Mean = 150.2, Standard Deviation = 30.81
# Specificity: Mean = 52.75, Standard Deviation = 9.35
# Accuracy: Mean = 61.36, Standard Deviation = 5.64
# Precision: Mean = 85.77, Standard Deviation = 2.08
# Recall: Mean = 63.28, Standard Deviation = 7.53
# F1-score: Mean = 72.61, Standard Deviation = 5.08
# G-Mean: Mean = 57.34, Standard Deviation = 4.94
# AUROC: Mean = 62.24, Standard Deviation = 5.05
# AUPRC: Mean = 87.26, Standard Deviation = 2.26
# FNR: Mean = 36.72, Standard Deviation = 7.53
# FPR: Mean = 47.25, Standard Deviation = 9.35
#
#
# Results for Ablation/ablation_tabnet/relu:
# TP: Mean = 262.2, Standard Deviation = 20.94
# TN: Mean = 42.2, Standard Deviation = 10.02
# FP: Mean = 48.8, Standard Deviation = 10.02
# FN: Mean = 146.8, Standard Deviation = 20.94
# Specificity: Mean = 46.37, Standard Deviation = 11.01
# Accuracy: Mean = 60.88, Standard Deviation = 3.57
# Precision: Mean = 84.38, Standard Deviation = 2.33
# Recall: Mean = 64.11, Standard Deviation = 5.12
# F1-score: Mean = 72.74, Standard Deviation = 3.25
# G-Mean: Mean = 53.96, Standard Deviation = 6.19
# AUROC: Mean = 58.52, Standard Deviation = 4.79
# AUPRC: Mean = 85.62, Standard Deviation = 2.19
# FNR: Mean = 35.89, Standard Deviation = 5.12
# FPR: Mean = 53.63, Standard Deviation = 11.01
#
#
# Results for Ablation/ablation_node/tree_increase:
# TP: Mean = 281.3, Standard Deviation = 68.75
# TN: Mean = 49.1, Standard Deviation = 26.14
# FP: Mean = 41.9, Standard Deviation = 26.14
# FN: Mean = 127.7, Standard Deviation = 68.75
# Specificity: Mean = 53.96, Standard Deviation = 28.72
# Accuracy: Mean = 66.08, Standard Deviation = 8.55
# Precision: Mean = 87.9, Standard Deviation = 3.3
# Recall: Mean = 68.78, Standard Deviation = 16.81
# F1-score: Mean = 75.94, Standard Deviation = 7.75
# G-Mean: Mean = 51.21, Standard Deviation = 26.99
# AUROC: Mean = 66.26, Standard Deviation = 5.99
# AUPRC: Mean = 88.87, Standard Deviation = 2.84
# FNR: Mean = 31.22, Standard Deviation = 16.81
# FPR: Mean = 46.04, Standard Deviation = 28.72
#
#
# Results for Ablation/ablation_node/entmax:
# TP: Mean = 264.5, Standard Deviation = 7.01
# TN: Mean = 57.6, Standard Deviation = 3.03
# FP: Mean = 33.4, Standard Deviation = 3.03
# FN: Mean = 144.5, Standard Deviation = 7.01
# Specificity: Mean = 63.3, Standard Deviation = 3.33
# Accuracy: Mean = 64.42, Standard Deviation = 1.02
# Precision: Mean = 88.8, Standard Deviation = 0.71
# Recall: Mean = 64.67, Standard Deviation = 1.71
# F1-score: Mean = 74.82, Standard Deviation = 1.0
# G-Mean: Mean = 63.94, Standard Deviation = 1.2
# AUROC: Mean = 71.6, Standard Deviation = 0.38
# AUPRC: Mean = 91.51, Standard Deviation = 0.28
# FNR: Mean = 35.33, Standard Deviation = 1.71
# FPR: Mean = 36.7, Standard Deviation = 3.33
#
#
# Results for Ablation/ablation_node/sparsemax:
# TP: Mean = 254.7, Standard Deviation = 26.51
# TN: Mean = 61.1, Standard Deviation = 5.61
# FP: Mean = 29.9, Standard Deviation = 5.61
# FN: Mean = 154.3, Standard Deviation = 26.51
# Specificity: Mean = 67.14, Standard Deviation = 6.16
# Accuracy: Mean = 63.16, Standard Deviation = 4.24
# Precision: Mean = 89.56, Standard Deviation = 0.83
# Recall: Mean = 62.27, Standard Deviation = 6.48
# F1-score: Mean = 73.27, Standard Deviation = 4.17
# G-Mean: Mean = 64.39, Standard Deviation = 0.96
# AUROC: Mean = 70.49, Standard Deviation = 0.88
# AUPRC: Mean = 91.26, Standard Deviation = 0.27
# FNR: Mean = 37.73, Standard Deviation = 6.48
# FPR: Mean = 32.86, Standard Deviation = 6.16
#
#
# Results for Ablation/ablation_node/low_depth:
# TP: Mean = 221.1, Standard Deviation = 23.77
# TN: Mean = 66.3, Standard Deviation = 3.59
# FP: Mean = 24.7, Standard Deviation = 3.59
# FN: Mean = 187.9, Standard Deviation = 23.77
# Specificity: Mean = 72.86, Standard Deviation = 3.95
# Accuracy: Mean = 57.48, Standard Deviation = 4.1
# Precision: Mean = 89.99, Standard Deviation = 0.67
# Recall: Mean = 54.06, Standard Deviation = 5.81
# F1-score: Mean = 67.36, Standard Deviation = 4.56
# G-Mean: Mean = 62.58, Standard Deviation = 2.01
# AUROC: Mean = 66.88, Standard Deviation = 1.91
# AUPRC: Mean = 88.65, Standard Deviation = 0.84
# FNR: Mean = 45.94, Standard Deviation = 5.81
# FPR: Mean = 27.14, Standard Deviation = 3.95
#
#
# Results for Ablation/ablation_node/gumbel_softmax:
# TP: Mean = 255.0, Standard Deviation = 15.57
# TN: Mean = 62.1, Standard Deviation = 3.57
# FP: Mean = 28.9, Standard Deviation = 3.57
# FN: Mean = 154.0, Standard Deviation = 15.57
# Specificity: Mean = 68.24, Standard Deviation = 3.93
# Accuracy: Mean = 63.42, Standard Deviation = 2.73
# Precision: Mean = 89.84, Standard Deviation = 0.87
# Recall: Mean = 62.35, Standard Deviation = 3.81
# F1-score: Mean = 73.54, Standard Deviation = 2.61
# G-Mean: Mean = 65.14, Standard Deviation = 1.73
# AUROC: Mean = 69.33, Standard Deviation = 0.94
# AUPRC: Mean = 90.0, Standard Deviation = 0.44
# FNR: Mean = 37.65, Standard Deviation = 3.81
# FPR: Mean = 31.76, Standard Deviation = 3.93
#
#
# Results for Ablation/ablation_node/softmax:
# TP: Mean = 270.0, Standard Deviation = 10.73
# TN: Mean = 57.4, Standard Deviation = 2.99
# FP: Mean = 33.6, Standard Deviation = 2.99
# FN: Mean = 139.0, Standard Deviation = 10.73
# Specificity: Mean = 63.08, Standard Deviation = 3.28
# Accuracy: Mean = 65.48, Standard Deviation = 1.67
# Precision: Mean = 88.95, Standard Deviation = 0.59
# Recall: Mean = 66.01, Standard Deviation = 2.62
# F1-score: Mean = 75.75, Standard Deviation = 1.58
# G-Mean: Mean = 64.47, Standard Deviation = 0.9
# AUROC: Mean = 71.67, Standard Deviation = 0.48
# AUPRC: Mean = 91.46, Standard Deviation = 0.24
# FNR: Mean = 33.99, Standard Deviation = 2.62
# FPR: Mean = 36.92, Standard Deviation = 3.28
#
#
# Results for Ablation/preliminary_ablation_tabnet/feature_dimension:
# TP: Mean = 281.33, Standard Deviation = 7.77
# TN: Mean = 58.0, Standard Deviation = 1.0
# FP: Mean = 33.0, Standard Deviation = 1.0
# FN: Mean = 127.67, Standard Deviation = 7.77
# Specificity: Mean = 63.74, Standard Deviation = 1.1
# Accuracy: Mean = 67.87, Standard Deviation = 1.36
# Precision: Mean = 89.5, Standard Deviation = 0.08
# Recall: Mean = 68.79, Standard Deviation = 1.9
# F1-score: Mean = 77.78, Standard Deviation = 1.2
# G-Mean: Mean = 66.2, Standard Deviation = 0.38
# AUROC: Mean = 71.05, Standard Deviation = 0.71
# AUPRC: Mean = 90.29, Standard Deviation = 0.81
# FNR: Mean = 31.21, Standard Deviation = 1.9
# FPR: Mean = 36.26, Standard Deviation = 1.1
#
#
# Results for Ablation/preliminary_ablation_tabnet/High_lambda:
# TP: Mean = 243.33, Standard Deviation = 47.25
# TN: Mean = 50.0, Standard Deviation = 10.39
# FP: Mean = 41.0, Standard Deviation = 10.39
# FN: Mean = 165.67, Standard Deviation = 47.25
# Specificity: Mean = 54.95, Standard Deviation = 11.42
# Accuracy: Mean = 58.67, Standard Deviation = 7.53
# Precision: Mean = 85.68, Standard Deviation = 1.28
# Recall: Mean = 59.49, Standard Deviation = 11.55
# F1-score: Mean = 69.75, Standard Deviation = 8.11
# G-Mean: Mean = 56.43, Standard Deviation = 1.68
# AUROC: Mean = 57.53, Standard Deviation = 2.19
# AUPRC: Mean = 84.71, Standard Deviation = 0.89
# FNR: Mean = 40.51, Standard Deviation = 11.55
# FPR: Mean = 45.05, Standard Deviation = 11.42
#
#
# Results for Ablation/preliminary_ablation_tabnet/Batch_size:
# TP: Mean = 223.33, Standard Deviation = 6.81
# TN: Mean = 53.67, Standard Deviation = 11.37
# FP: Mean = 37.33, Standard Deviation = 11.37
# FN: Mean = 185.67, Standard Deviation = 6.81
# Specificity: Mean = 58.97, Standard Deviation = 12.5
# Accuracy: Mean = 55.4, Standard Deviation = 3.22
# Precision: Mean = 85.75, Standard Deviation = 3.88
# Recall: Mean = 54.6, Standard Deviation = 1.66
# F1-score: Mean = 66.71, Standard Deviation = 2.18
# G-Mean: Mean = 56.55, Standard Deviation = 6.68
# AUROC: Mean = 59.15, Standard Deviation = 8.75
# AUPRC: Mean = 85.31, Standard Deviation = 2.29
# FNR: Mean = 45.4, Standard Deviation = 1.66
# FPR: Mean = 41.03, Standard Deviation = 12.5
